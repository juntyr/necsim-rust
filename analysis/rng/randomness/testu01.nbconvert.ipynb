# %%
import subprocess
import shlex
import re

import numpy as np

from IPython.display import display, Markdown
from tqdm import tqdm

# %%
CC_PATTERN = re.compile(r"(?<!^)(?=[A-Z])")

# %% [markdown]
# # TestU01 - empirical randomness testing

# %%
def test_randomness_testu01(
    mode, seeds=[42], args=[]
):
    outputs = []
    
    for seed in tqdm(seeds):
        generator = subprocess.Popen(shlex.split(
            f"cargo run --release --quiet -- --seed {seed} {CC_PATTERN.sub('-', mode).lower()}"
        ), stdout=subprocess.PIPE)
        testu01 = subprocess.run(
            shlex.split(f"./testu01") + args, stdin=generator.stdout,
            check=True, capture_output=True, text=True
        )

        outputs.append(testu01.stdout)
        
    most_suspect = None
    
    for output in outputs:
        summary_index = output.find("Summary results")
        failing_beg_index = output.find("----------------------------------------------", summary_index)
        
        if failing_beg_index == -1:
            failing_tests = 0
        else:
            failing_end_index = output.find("----------------------------------------------", failing_beg_index + 46)
        
            failing_tests = output[failing_beg_index:failing_end_index].count("\n") - 1
        
        if (most_suspect is None) or (failing_tests > most_suspect[0]):
            most_suspect = (failing_tests, output)
    
    

    if "All other tests were passed" in most_suspect[1]:
        display(Markdown(f"## <span style='color:red'><u>{mode}</u></span>"))
    else:
        display(Markdown(f"## <span style='color:green'>{mode}</span>"))
        
    display(Markdown("#### Test output (most suspect):"))
    display(Markdown(">" + most_suspect[1].replace('\n', '\n>')))

    display(Markdown("#### Parameters:"))
    display(Markdown(f"* seeds: {seeds}"))

# %%
for mode in ["Monolithic", "Independent", "IndependentSimulation", "IndependentSimulationNoDispersal"]:
    seeds = np.random.randint(0, np.iinfo("uint64").max, dtype="uint64", size=1)
    
    test_randomness_testu01(mode, seeds=seeds, args=["-s"])
    test_randomness_testu01(mode, seeds=seeds, args=["-s", "-H"])
    
    test_randomness_testu01(mode, seeds=seeds, args=["-c"])
    test_randomness_testu01(mode, seeds=seeds, args=["-c", "-H"])
    
    test_randomness_testu01(mode, seeds=seeds, args=["-b"])
    test_randomness_testu01(mode, seeds=seeds, args=["-b", "-H"])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:29<00:00, 29.12s/it]
# ## <span style='color:green'>Monolithic</span>
# #### Test output (most suspect):
# >==seed: 12345678
# >==stdin64
# >xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# >                 Starting SmallCrush
# >                 Version: TestU01 1.2.3
# >xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  1,  n = 5000000,  r =  0,    d = 1073741824,    t = 2,    p = 1
# >
# >
# >      Number of cells = d^t = 1152921504606846976
# >      Lambda = Poisson mean =      27.1051
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :      27.11
# >Total observed number                 :      30
# >p-value of test                       :    0.31
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.35
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test sknuth_Collision calling smultin_Multinomial
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_Multinomial test:
# >-----------------------------------------------
# >   N =  1,  n = 5000000,  r =  0,   d = 65536,   t =  2,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =         4294967296
# >       Expected number per cell =  1 /  858.99346
# >       EColl = n^2 / (2k) =  2910.383046
# >       Hashing =   TRUE
# >
# >       Collision test,    Mu =      2909.2534,    Sigma =    53.8957
# >
# >-----------------------------------------------
# >Test Results for Collisions
# >
# >Expected number of collisions = Mu    :     2909.25
# >Observed number of collisions         :     2911
# >p-value of test                       :    0.49
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :       4289970207
# >  j =  1                              :          4994182
# >  j =  2                              :             2903
# >  j =  3                              :                4
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.46
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_Gap test:
# >-----------------------------------------------
# >   N =  1,  n = 200000,  r = 22,   Alpha =        0,   Beta  = 0.00390625
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          : 1114
# >Chi-square statistic                  : 1058.84
# >p-value of test                       :    0.88
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.16
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_SimpPoker test:
# >-----------------------------------------------
# >   N =  1,  n = 400000,  r = 24,   d =   64,   k =   64
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   19
# >Chi-square statistic                  :   17.08
# >p-value of test                       :    0.58
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.75
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_CouponCollector test:
# >-----------------------------------------------
# >   N =  1,  n = 500000,  r = 26,   d =   16
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   44
# >Chi-square statistic                  :   45.29
# >p-value of test                       :    0.42
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.66
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_MaxOft test:
# >-----------------------------------------------
# >   N =  1,  n = 2000000,  r =  0,   d = 100000,   t =  6
# >
# >      Number of categories = 100000
# >      Expected number per category  = 20.00
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          : 99999
# >Chi-square statistic                  : 1.00e+5
# >p-value of test                       :    0.45
# >
# >
# >-----------------------------------------------
# >Anderson-Darling statistic            :    0.75
# >p-value of test                       :    0.25
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.16
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >svaria_WeightDistrib test:
# >-----------------------------------------------
# >   N =  1,  n = 200000,  r = 27,  k = 256,  Alpha =      0,  Beta =  0.125
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   41
# >Chi-square statistic                  :   44.66
# >p-value of test                       :    0.32
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.19
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_MatrixRank test:
# >-----------------------------------------------
# >   N =  1,  n = 20000,  r = 20,    s = 10,    L = 60,    k = 60
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :    3
# >Chi-square statistic                  :    0.46
# >p-value of test                       :    0.93
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.78
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N =  1,  n = 500000,  r = 20,   s = 10,   L = 300,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >Number of degrees of freedom          : 2209
# >Chi-square statistic                  : 2200.47
# >p-value of test                       :    0.55
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.85
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >swalk_RandomWalk1 test:
# >-----------------------------------------------
# >   N =  1,  n = 1000000,  r =  0,   s = 30,   L0 =  150,   L1 =  150
# >
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic H
# >
# >Number of degrees of freedom          :   52
# >ChiSquare statistic                   :   60.10
# >p-value of test                       :    0.21
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic M
# >
# >Number of degrees of freedom          :   52
# >ChiSquare statistic                   :   44.61
# >p-value of test                       :    0.76
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic J
# >
# >Number of degrees of freedom          :   75
# >ChiSquare statistic                   :   61.86
# >p-value of test                       :    0.86
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic R
# >
# >Number of degrees of freedom          :   44
# >ChiSquare statistic                   :   45.71
# >p-value of test                       :    0.40
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic C
# >
# >Number of degrees of freedom          :   26
# >ChiSquare statistic                   :   32.38
# >p-value of test                       :    0.18
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.71
# >
# >Generator state:
# >
# >
# >
# >
# >
# >========= Summary results of SmallCrush =========
# >
# > Version:          TestU01 1.2.3
# > Generator:        stdin64 lsb 32-bits
# > Number of statistics:  15
# > Total CPU time:   00:00:11.10
# >
# > All tests were passed
# >
# >
# >
# >
# #### Parameters:
# * seeds: [14508787790522350205]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:16<00:00, 16.32s/it]
# ## <span style='color:green'>Monolithic</span>
# #### Test output (most suspect):
# >==seed: 12345678
# >==stdin64
# >xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# >                 Starting SmallCrush
# >                 Version: TestU01 1.2.3
# >xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  1,  n = 5000000,  r =  0,    d = 1073741824,    t = 2,    p = 1
# >
# >
# >      Number of cells = d^t = 1152921504606846976
# >      Lambda = Poisson mean =      27.1051
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :      27.11
# >Total observed number                 :      37
# >p-value of test                       :    0.04
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.64
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test sknuth_Collision calling smultin_Multinomial
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >smultin_Multinomial test:
# >-----------------------------------------------
# >   N =  1,  n = 5000000,  r =  0,   d = 65536,   t =  2,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =         4294967296
# >       Expected number per cell =  1 /  858.99346
# >       EColl = n^2 / (2k) =  2910.383046
# >       Hashing =   TRUE
# >
# >       Collision test,    Mu =      2909.2534,    Sigma =    53.8957
# >
# >-----------------------------------------------
# >Test Results for Collisions
# >
# >Expected number of collisions = Mu    :     2909.25
# >Observed number of collisions         :     2971
# >p-value of test                       :    0.13
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :       4289970267
# >  j =  1                              :          4994058
# >  j =  2                              :             2971
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.53
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sknuth_Gap test:
# >-----------------------------------------------
# >   N =  1,  n = 200000,  r = 22,   Alpha =        0,   Beta  = 0.00390625
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          : 1114
# >Chi-square statistic                  : 1080.38
# >p-value of test                       :    0.76
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.20
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sknuth_SimpPoker test:
# >-----------------------------------------------
# >   N =  1,  n = 400000,  r = 24,   d =   64,   k =   64
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   19
# >Chi-square statistic                  :   27.10
# >p-value of test                       :    0.10
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.71
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sknuth_CouponCollector test:
# >-----------------------------------------------
# >   N =  1,  n = 500000,  r = 26,   d =   16
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   44
# >Chi-square statistic                  :   48.97
# >p-value of test                       :    0.28
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.62
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sknuth_MaxOft test:
# >-----------------------------------------------
# >   N =  1,  n = 2000000,  r =  0,   d = 100000,   t =  6
# >
# >      Number of categories = 100000
# >      Expected number per category  = 20.00
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          : 99999
# >Chi-square statistic                  :99311.50
# >p-value of test                       :    0.94
# >
# >
# >-----------------------------------------------
# >Anderson-Darling statistic            :    0.92
# >p-value of test                       :    0.08
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.20
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >svaria_WeightDistrib test:
# >-----------------------------------------------
# >   N =  1,  n = 200000,  r = 27,  k = 256,  Alpha =      0,  Beta =  0.125
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   41
# >Chi-square statistic                  :   43.67
# >p-value of test                       :    0.36
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.17
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >smarsa_MatrixRank test:
# >-----------------------------------------------
# >   N =  1,  n = 20000,  r = 20,    s = 10,    L = 60,    k = 60
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :    3
# >Chi-square statistic                  :    1.12
# >p-value of test                       :    0.77
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.67
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N =  1,  n = 500000,  r = 20,   s = 10,   L = 300,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >Number of degrees of freedom          : 2209
# >Chi-square statistic                  : 2228.67
# >p-value of test                       :    0.38
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:00.90
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >swalk_RandomWalk1 test:
# >-----------------------------------------------
# >   N =  1,  n = 1000000,  r =  0,   s = 30,   L0 =  150,   L1 =  150
# >
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic H
# >
# >Number of degrees of freedom          :   52
# >ChiSquare statistic                   :   59.70
# >p-value of test                       :    0.22
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic M
# >
# >Number of degrees of freedom          :   52
# >ChiSquare statistic                   :   65.38
# >p-value of test                       :    0.10
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic J
# >
# >Number of degrees of freedom          :   75
# >ChiSquare statistic                   :   67.58
# >p-value of test                       :    0.72
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic R
# >
# >Number of degrees of freedom          :   44
# >ChiSquare statistic                   :   41.70
# >p-value of test                       :    0.57
# >
# >
# >-----------------------------------------------
# >Test on the values of the Statistic C
# >
# >Number of degrees of freedom          :   26
# >ChiSquare statistic                   :   22.95
# >p-value of test                       :    0.64
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:01.83
# >
# >Generator state:
# >
# >
# >
# >
# >
# >========= Summary results of SmallCrush =========
# >
# > Version:          TestU01 1.2.3
# > Generator:        stdin64 msb 32-bits
# > Number of statistics:  15
# > Total CPU time:   00:00:11.52
# >
# > All tests were passed
# >
# >
# >
# >
# #### Parameters:
# * seeds: [14508787790522350205]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [57:22<00:00, 3442.81s/it]
# ## <span style='color:red'><u>Monolithic</u></span>
# #### Test output (most suspect):
# >==seed: 12345678
# >==stdin64
# >xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# >                 Starting Crush
# >                 Version: TestU01 1.2.3
# >xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# >
# >
# >***********************************************************
# >Test smarsa_SerialOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N =  1,  n = 500000000,  r =  0,   d = 4096,   t =  2,
# >       Sparse =  FALSE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =           16777216
# >       Expected number per cell =   29.802322
# >       Hashing =  FALSE
# >
# >   For Delta > -1, we use the ChiSquare approximation
# >   Correction factor of the ChiSquare:
# >       Delta =     1,    Mu =     0.01677312,    Sigma =          1
# >
# >-----------------------------------------------
# >Test Results for Delta =   1.0000
# >
# >Number of degrees of freedom          : 16773120
# >Value of the statistic                : 1.68e+7
# >p-value of test                       :    0.05
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:10.92
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_SerialOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N =  1,  n = 300000000,  r =  0,   d =   64,   t =  4,
# >       Sparse =  FALSE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =           16777216
# >       Expected number per cell =   17.881393
# >       Hashing =  FALSE
# >
# >   For Delta > -1, we use the ChiSquare approximation
# >   Correction factor of the ChiSquare:
# >       Delta =     1,    Mu =    0.027525119,    Sigma =          1
# >
# >-----------------------------------------------
# >Test Results for Delta =   1.0000
# >
# >Number of degrees of freedom          : 16515072
# >Value of the statistic                : 1.65e+7
# >p-value of test                       :    0.9953
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:43.17
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r =  0,   d = 1048576,   t =  2,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.75
# >Observed number of collisions         :      484
# >p-value of test                       :    0.09
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278244
# >  j =  1                              :         99999032
# >  j =  2                              :              484
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:47.71
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r = 10,   d = 1048576,   t =  2,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.75
# >Observed number of collisions         :      493
# >p-value of test                       :    0.04
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278253
# >  j =  1                              :         99999014
# >  j =  2                              :              493
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:47.72
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r =  0,   d = 1024,   t =  4,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.75
# >Observed number of collisions         :      457
# >p-value of test                       :    0.46
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278217
# >  j =  1                              :         99999086
# >  j =  2                              :              457
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:06.25
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r = 20,   d = 1024,   t =  4,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.75
# >Observed number of collisions         :      480
# >p-value of test                       :    0.12
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278240
# >  j =  1                              :         99999040
# >  j =  2                              :              480
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:05.88
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r =  0,   d =   32,   t =  8,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.75
# >Observed number of collisions         :      453
# >p-value of test                       :    0.52
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278213
# >  j =  1                              :         99999094
# >  j =  2                              :              453
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:06.13
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r = 25,   d =   32,   t =  8,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.75
# >Observed number of collisions         :      461
# >p-value of test                       :    0.39
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278221
# >  j =  1                              :         99999078
# >  j =  2                              :              461
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:06.32
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r =  0,   d =    4,   t = 20,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.74
# >Observed number of collisions         :      419
# >p-value of test                       :    0.95
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278179
# >  j =  1                              :         99999162
# >  j =  2                              :              419
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:06.45
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >Test smarsa_CollisionOver calling smultin_MultinomialOver
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smultin_MultinomialOver test:
# >-----------------------------------------------
# >   N = 10,  n = 10000000,  r = 28,   d =    4,   t = 20,
# >       Sparse =   TRUE
# >
# >       GenerCell = smultin_GenerCellSerial
# >       Number of cells = d^t =      1099511627776
# >       Expected number per cell =  1 /  109951.16
# >       EColl = n^2 / (2k) =  45.47473509
# >       Hashing =   TRUE
# >
# >       Collision test
# >
# >       CollisionOver:   density = n / k =  1 /  109951.16
# >       Expected number of collisions = Mu =      45.47
# >
# >
# >-----------------------------------------------
# >Results of CollisionOver test:
# >
# >POISSON approximation                 :
# >Expected number of collisions = N*Mu  :      454.74
# >Observed number of collisions         :      457
# >p-value of test                       :    0.46
# >
# >-----------------------------
# >Total number of cells containing j balls
# >
# >  j =  0                              :   10995016278217
# >  j =  1                              :         99999086
# >  j =  2                              :              457
# >  j =  3                              :                0
# >  j =  4                              :                0
# >  j =  5                              :                0
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:05.90
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  5,  n = 20000000,  r =  0,    d = 2147483648,    t = 2,    p = 1
# >
# >
# >      Number of cells = d^t = 4611686018427387904
# >      Lambda = Poisson mean =     433.6809
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :    2168.40
# >Total observed number                 :    2205
# >p-value of test                       :    0.22
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:34.84
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  5,  n = 20000000,  r =  0,    d = 2097152,    t = 3,    p = 1
# >
# >
# >      Number of cells = d^t = 9223372036854775808
# >      Lambda = Poisson mean =     216.8404
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :    1084.20
# >Total observed number                 :    1063
# >p-value of test                       :    0.73
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:37.08
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  5,  n = 20000000,  r =  0,    d = 65536,    t = 4,    p = 1
# >
# >
# >      Number of cells = d^t = 18446744073709551616
# >      Lambda = Poisson mean =     108.4202
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :     542.10
# >Total observed number                 :     547
# >p-value of test                       :    0.42
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:38.87
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  3,  n = 20000000,  r =  0,    d = 512,    t = 7,    p = 1
# >
# >
# >      Number of cells = d^t = 9223372036854775808
# >      Lambda = Poisson mean =     216.8404
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :     650.52
# >Total observed number                 :     677
# >p-value of test                       :    0.15
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:27.20
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  3,  n = 20000000,  r =  7,    d = 512,    t = 7,    p = 1
# >
# >
# >      Number of cells = d^t = 9223372036854775808
# >      Lambda = Poisson mean =     216.8404
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :     650.52
# >Total observed number                 :     641
# >p-value of test                       :    0.64
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:27.62
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  3,  n = 20000000,  r = 14,    d = 256,    t = 8,    p = 1
# >
# >
# >      Number of cells = d^t = 18446744073709551616
# >      Lambda = Poisson mean =     108.4202
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :     325.26
# >Total observed number                 :     338
# >p-value of test                       :    0.25
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:29.29
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >smarsa_BirthdaySpacings test:
# >-----------------------------------------------
# >   N =  3,  n = 20000000,  r = 22,    d = 256,    t = 8,    p = 1
# >
# >
# >      Number of cells = d^t = 18446744073709551616
# >      Lambda = Poisson mean =     108.4202
# >
# >
# >----------------------------------------------------
# >Total expected number = N*Lambda      :     325.26
# >Total observed number                 :     293
# >p-value of test                       :    0.96
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:29.59
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >snpair_ClosePairs test:
# >-----------------------------------------------
# >   N = 10,  n = 2000000,  r =  0,  t = 2,  p = 0,  m = 30,  Torus =  TRUE
# >
# >
# >---------------------------------------
# >Test based on the 2 nearest points (NP):
# >
# >Stat. AD on the N values (NP)         :    0.44
# >p-value of test                       :    0.81
# >
# >
# >A2 test based on the spacings between the
# >   successive jump times of process Y_n(t):
# >
# >A2 test on the values of A2 (m-NP)    :    0.43
# >p-value of test                       :    0.81
# >
# >Test on the Nm values of W_{n,i}(mNP1):    0.68
# >p-value of test                       :    0.58
# >
# >Test on the jump times of Y
# >   (superposition of Yn):
# >
# >Expected number of jumps of Y = mN    :     300
# >Number of jumps of Y                  :     295
# >p-value of test                       :    0.60
# >
# >Stat. AD (mNP2)                       :    1.25
# >p-value of test                       :    0.25
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:13.48
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >snpair_ClosePairs test:
# >-----------------------------------------------
# >   N = 10,  n = 2000000,  r =  0,  t = 3,  p = 0,  m = 30,  Torus =  TRUE
# >
# >
# >---------------------------------------
# >Test based on the 2 nearest points (NP):
# >
# >Stat. AD on the N values (NP)         :    0.77
# >p-value of test                       :    0.50
# >
# >
# >A2 test based on the spacings between the
# >   successive jump times of process Y_n(t):
# >
# >A2 test on the values of A2 (m-NP)    :    0.93
# >p-value of test                       :    0.39
# >
# >Test on the Nm values of W_{n,i}(mNP1):    0.75
# >p-value of test                       :    0.52
# >
# >Test on the jump times of Y
# >   (superposition of Yn):
# >
# >Expected number of jumps of Y = mN    :     300
# >Number of jumps of Y                  :     284
# >p-value of test                       :    0.81
# >
# >Stat. AD (mNP2)                       :    3.25
# >p-value of test                       :    0.02
# >
# >Stat. AD after spacings (mNP2-S)      :    0.30
# >p-value of test                       :    0.94
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:17.72
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >snpair_ClosePairs test:
# >-----------------------------------------------
# >   N =  5,  n = 2000000,  r =  0,  t = 7,  p = 0,  m = 30,  Torus =  TRUE
# >
# >
# >---------------------------------------
# >Test based on the 2 nearest points (NP):
# >
# >Stat. AD on the N values (NP)         :    0.36
# >p-value of test                       :    0.88
# >
# >
# >A2 test based on the spacings between the
# >   successive jump times of process Y_n(t):
# >
# >A2 test on the values of A2 (m-NP)    :    2.99
# >p-value of test                       :    0.03
# >
# >Test on the Nm values of W_{n,i}(mNP1):    0.14
# >p-value of test                       :    0.9992    *****
# >
# >Test on the jump times of Y
# >   (superposition of Yn):
# >
# >Expected number of jumps of Y = mN    :     150
# >Number of jumps of Y                  :     146
# >p-value of test                       :    0.61
# >
# >Stat. AD (mNP2)                       :    1.32
# >p-value of test                       :    0.22
# >
# >Stat. AD after spacings (mNP2-S)      :    1.69
# >p-value of test                       :    0.14
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:30.98
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >snpair_ClosePairsBitMatch test:
# >-----------------------------------------------
# >   N =  4,  n = 4000000,  r =  0,  t = 2
# >
# >
# >-----------------------------------------------
# >Max of all bit distances              :   23.00
# >p-value of test                       :    0.11
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:12.03
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >snpair_ClosePairsBitMatch test:
# >-----------------------------------------------
# >   N =  2,  n = 4000000,  r =  0,  t = 4
# >
# >
# >-----------------------------------------------
# >Max of all bit distances              :   11.00
# >p-value of test                       :    0.06
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:10.90
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_SimpPoker test:
# >-----------------------------------------------
# >   N =  1,  n = 40000000,  r =  0,   d =   16,   k =   16
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   12
# >Chi-square statistic                  :    7.09
# >p-value of test                       :    0.85
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:17.27
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_SimpPoker test:
# >-----------------------------------------------
# >   N =  1,  n = 40000000,  r = 26,   d =   16,   k =   16
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   12
# >Chi-square statistic                  :   11.81
# >p-value of test                       :    0.46
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:17.20
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_SimpPoker test:
# >-----------------------------------------------
# >   N =  1,  n = 10000000,  r =  0,   d =   64,   k =   64
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   23
# >Chi-square statistic                  :   23.02
# >p-value of test                       :    0.46
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:16.87
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_SimpPoker test:
# >-----------------------------------------------
# >   N =  1,  n = 10000000,  r = 24,   d =   64,   k =   64
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   23
# >Chi-square statistic                  :   12.70
# >p-value of test                       :    0.96
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:17.74
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_CouponCollector test:
# >-----------------------------------------------
# >   N =  1,  n = 40000000,  r =  0,   d =    4
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   51
# >Chi-square statistic                  :   48.32
# >p-value of test                       :    0.58
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:08.72
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_CouponCollector test:
# >-----------------------------------------------
# >   N =  1,  n = 40000000,  r = 28,   d =    4
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   51
# >Chi-square statistic                  :   65.47
# >p-value of test                       :    0.08
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:09.23
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_CouponCollector test:
# >-----------------------------------------------
# >   N =  1,  n = 10000000,  r =  0,   d =   16
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   46
# >Chi-square statistic                  :   53.25
# >p-value of test                       :    0.22
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:12.49
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_CouponCollector test:
# >-----------------------------------------------
# >   N =  1,  n = 10000000,  r = 26,   d =   16
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :   46
# >Chi-square statistic                  :   40.60
# >p-value of test                       :    0.70
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:13.48
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# >sknuth_Gap test:
# >-----------------------------------------------
# >   N =  1,  n = 100000000,  r =  0,   Alpha =        0,   Beta  =    0.125
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :  106
# >Chi-square statistic                  :  120.34
# >p-value of test                       :    0.16
# >
# >-----------------------------------------------
# >CPU time used                    :  00:00:17.71
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 lsb 32-bits
# >
# >
# ...
# >-----------------------------------------------
# >   N =  1,  n = 1000,  r = 27,   s = 3,   L = 10000020
# >
# >
# >-----------------------------------------------
# >Number of degrees of freedom          :    8
# >Chi-square statistic                  :    2.76
# >p-value of test                       :    0.95
# >
# >-----------------------------------------------
# >Global longest run of 1               :   30.00
# >p-value of test                       :    0.90
# >
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:52.05
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_PeriodsInStrings test:
# >-----------------------------------------------
# >   N = 10,  n = 500000000,  r =  0,   s =   10
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.21
# >p-value of test                       :    0.36
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.18
# >p-value of test                       :    0.46
# >
# >Anderson-Darling statistic = A2       :    0.86
# >p-value of test                       :    0.44
# >
# >Test on the sum of all N observations
# >Number of degrees of freedom          :  200
# >Chi-square statistic                  :  194.40
# >p-value of test                       :    0.60
# >
# >-----------------------------------------------
# >CPU time used                    :  00:03:03.54
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_PeriodsInStrings test:
# >-----------------------------------------------
# >   N = 10,  n = 500000000,  r = 20,   s =   10
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.13
# >p-value of test                       :    0.67
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.17
# >p-value of test                       :    0.51
# >
# >Anderson-Darling statistic = A2       :    0.40
# >p-value of test                       :    0.84
# >
# >Test on the sum of all N observations
# >Number of degrees of freedom          :  200
# >Chi-square statistic                  :  200.51
# >p-value of test                       :    0.48
# >
# >-----------------------------------------------
# >CPU time used                    :  00:03:34.20
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingWeight2 test:
# >-----------------------------------------------
# >   N = 10,  n = 1000000000,  r =  0,   s = 3,   L = 1000000
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.29
# >p-value of test                       :    0.15
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.11
# >p-value of test                       :    0.73
# >
# >Anderson-Darling statistic = A2       :    0.81
# >p-value of test                       :    0.47
# >
# >Test on the sum of all N observations
# >Number of degrees of freedom          : 10000
# >Chi-square statistic                  : 9883.38
# >p-value of test                       :    0.79
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:22.65
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingWeight2 test:
# >-----------------------------------------------
# >   N = 10,  n = 1000000000,  r = 27,   s = 3,   L = 1000000
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.22
# >p-value of test                       :    0.34
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.11
# >p-value of test                       :    0.73
# >
# >Anderson-Darling statistic = A2       :    0.53
# >p-value of test                       :    0.71
# >
# >Test on the sum of all N observations
# >Number of degrees of freedom          : 10000
# >Chi-square statistic                  : 9918.40
# >p-value of test                       :    0.72
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:20.53
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingCorr test:
# >-----------------------------------------------
# >   N =  1,  n = 1000000000,  r = 10,   s = 10,   L = 30
# >
# >
# >
# >-----------------------------------------------
# >Normal statistic                      :   -1.93
# >p-value of test                       :    0.97
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:26.92
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingCorr test:
# >-----------------------------------------------
# >   N =  1,  n = 100000000,  r = 10,   s = 10,   L = 300
# >
# >
# >
# >-----------------------------------------------
# >Normal statistic                      :    1.17
# >p-value of test                       :    0.12
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:25.60
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingCorr test:
# >-----------------------------------------------
# >   N =  1,  n = 100000000,  r = 10,   s = 10,   L = 1200
# >
# >
# >
# >-----------------------------------------------
# >Normal statistic                      :   -0.81
# >p-value of test                       :    0.79
# >
# >-----------------------------------------------
# >CPU time used                    :  00:05:38.78
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N = 10,  n = 30000000,  r =  0,   s = 3,   L = 30,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.26
# >p-value of test                       :    0.21
# >
# >Kolmogorov-Smirnov- statistic = D-    :   0.066
# >p-value of test                       :    0.88
# >
# >Anderson-Darling statistic = A2       :    0.89
# >p-value of test                       :    0.42
# >
# >Test on the sum of all N observations
# >Number of degrees of freedom          : 4890
# >Chi-square statistic                  : 4778.44
# >p-value of test                       :    0.87
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:29.78
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N = 10,  n = 30000000,  r = 27,   s = 3,   L = 30,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :   0.024
# >p-value of test                       :    0.97
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.31
# >p-value of test                       :    0.11
# >
# >Anderson-Darling statistic = A2       :    1.34
# >p-value of test                       :    0.22
# >
# >Test on the sum of all N observations
# >Number of degrees of freedom          : 4890
# >Chi-square statistic                  : 5047.69
# >p-value of test                       :    0.06
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:31.97
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N =  1,  n = 30000000,  r =  0,   s = 4,   L = 300,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >Number of degrees of freedom          : 4117
# >Chi-square statistic                  : 4125.11
# >p-value of test                       :    0.46
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:52.15
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N =  1,  n = 30000000,  r = 26,   s = 4,   L = 300,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >Number of degrees of freedom          : 4117
# >Chi-square statistic                  : 4266.43
# >p-value of test                       :    0.05
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:53.80
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N =  1,  n = 10000000,  r =  0,   s = 5,   L = 1200,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >Number of degrees of freedom          : 11825
# >Chi-square statistic                  :11763.38
# >p-value of test                       :    0.65
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:01.93
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_HammingIndep test:
# >-----------------------------------------------
# >   N =  1,  n = 10000000,  r = 25,   s = 5,   L = 1200,   d = 0
# >
# >
# >
# >Counters with expected numbers >= 10
# >-----------------------------------------------
# >Number of degrees of freedom          : 11825
# >Chi-square statistic                  :11713.96
# >p-value of test                       :    0.76
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:01.38
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_Run test:
# >-----------------------------------------------
# >   N =  1,  n = 2000000000,  r =  0,   s =    3
# >
# >
# >-----------------------------------------------
# >Total number of 1 runs:  2000000000
# >
# >Number of degrees of freedom          :   54
# >Chi2 statistic for number of runs     :   72.72
# >p-value of test                       :    0.05
# >
# >
# >-----------------------------------------------
# >Total number of bits:  8000017950
# >
# >Normal statistic for number of bits   :    0.14
# >p-value of test                       :    0.44
# >
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:28.14
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_Run test:
# >-----------------------------------------------
# >   N =  1,  n = 2000000000,  r = 27,   s =    3
# >
# >
# >-----------------------------------------------
# >Total number of 1 runs:  2000000000
# >
# >Number of degrees of freedom          :   54
# >Chi2 statistic for number of runs     :   55.50
# >p-value of test                       :    0.42
# >
# >
# >-----------------------------------------------
# >Total number of bits:  8000144730
# >
# >Normal statistic for number of bits   :    1.14
# >p-value of test                       :    0.13
# >
# >
# >
# >-----------------------------------------------
# >CPU time used                    :  00:01:30.14
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_AutoCor test:
# >-----------------------------------------------
# >   N = 10,  n = 1000000030,  r =  0,   s = 3,   d = 1
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :   0.042
# >p-value of test                       :    0.94
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.28
# >p-value of test                       :    0.18
# >
# >Anderson-Darling statistic = A2       :    2.21
# >p-value of test                       :    0.07
# >
# >Tests on the sum of all N observations
# >Standardized normal statistic         :    1.91
# >p-value of test                       :    0.03
# >
# >Sample variance                       :    1.61
# >p-value of test                       :    0.11
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:48.32
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_AutoCor test:
# >-----------------------------------------------
# >   N = 10,  n = 1000000029,  r =  0,   s = 3,   d = 3
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.22
# >p-value of test                       :    0.34
# >
# >Kolmogorov-Smirnov- statistic = D-    :    0.11
# >p-value of test                       :    0.74
# >
# >Anderson-Darling statistic = A2       :    0.58
# >p-value of test                       :    0.66
# >
# >Tests on the sum of all N observations
# >Standardized normal statistic         :   -0.36
# >p-value of test                       :    0.64
# >
# >Sample variance                       :    1.07
# >p-value of test                       :    0.38
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:29.46
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_AutoCor test:
# >-----------------------------------------------
# >   N = 10,  n = 1000000030,  r = 27,   s = 3,   d = 1
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.35
# >p-value of test                       :    0.06
# >
# >Kolmogorov-Smirnov- statistic = D-    :   0.092
# >p-value of test                       :    0.80
# >
# >Anderson-Darling statistic = A2       :    2.24
# >p-value of test                       :    0.07
# >
# >Tests on the sum of all N observations
# >Standardized normal statistic         :   -1.36
# >p-value of test                       :    0.91
# >
# >Sample variance                       :    1.80
# >p-value of test                       :    0.06
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:49.73
# >
# >Generator state:
# >
# >
# >
# >
# >***********************************************************
# >HOST = lb-jrosinde3, Linux
# >
# >stdin64 msb 32-bits
# >
# >
# >sstring_AutoCor test:
# >-----------------------------------------------
# >   N = 10,  n = 1000000029,  r = 27,   s = 3,   d = 3
# >
# >
# >-----------------------------------------------
# >
# >Kolmogorov-Smirnov+ statistic = D+    :    0.26
# >p-value of test                       :    0.21
# >
# >Kolmogorov-Smirnov- statistic = D-    :   0.070
# >p-value of test                       :    0.87
# >
# >Anderson-Darling statistic = A2       :    0.78
# >p-value of test                       :    0.49
# >
# >Tests on the sum of all N observations
# >Standardized normal statistic         :   -0.81
# >p-value of test                       :    0.79
# >
# >Sample variance                       :    0.50
# >p-value of test                       :    0.87
# >
# >-----------------------------------------------
# >CPU time used                    :  00:02:33.22
# >
# >Generator state:
# >
# >
# >
# >
# >
# >========= Summary results of BigCrush =========
# >
# > Version:          TestU01 1.2.3
# > Generator:        stdin64 msb 32-bits
# > Number of statistics:  160
# > Total CPU time:   04:28:02.90
# >
# > All tests were passed
# >
# >
# >
# >
# #### Parameters:
# * seeds: [9483868109318282069]
